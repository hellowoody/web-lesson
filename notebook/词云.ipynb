# %% [markdown]
# # 词云
#  - 安装所需的库：
#      - wordcloud: 用于生成词云。
#      - jieba: 用于中文分词。
#      - PIL or imageio: 用于处理图像。
#        - 确保你的掩模图像（mask-image.png）是黑白的，其中黑色的部分将会被填充上文字。
#        - 图像路径'path/to/your/mask-image.png'需要替换为你实际的文件路径。
#        - 你也可以使用其他库如PIL来处理掩模图像，但在这个例子中我们使用了imageio
#      - matplotlib: 用于显示图像。
#  - 导入必要的库。
#
#    ```
#     pip install --upgrade wordcloud imageio matplotlib jieba
#    ```
#
#  - 准备中文文本数据。
#  - 加载并处理掩模图像。
#  - 设置支持中文的字体。
#  - 创建并配置词云对象。
#  - 生成词云。

# %%
# pip install -q --upgrade wordcloud imageio matplotlib jieba

# %% [markdown]
# ## 第一步：导入必要的库

# %%
from wordcloud import WordCloud
import jieba
import matplotlib.pyplot as plt
import imageio  # 使用imageio来加载图像

# %% [markdown]
# ## 第二步：准备文本数据
# 假设我们已经有了一个文本字符串，或者从文件中读取文本数据。这里我们将直接定义一个字符串作为示例：

# %%
text = """
PUA你 CPU你 KTV你 PPT你 UFO你 M3 又幸福了姐 配享太庙 一吃一个不吱声 小孩姐 小孩哥 公主请上车 哈哈哈~惹到我算是提到棉花啦 
冤种 小镇做题家 团长 退！退！退！ 龙行龘龘 前程朤朤 智能+ 快手短视频 脱光 996 碳中和 city不city 健康最贵 生命无价 好家伙 
真有你的 原来如此 大可不必 人间不值得 打工人 干饭人 野性消费 一键三连 后浪 破防了 有内味儿了 绝绝子 硬核 躺平 二次元 真香警告 
U1S1 暴躁老哥 懂王 老父亲 电子竞技没有爱情 为爱发电 一键复制
"""

# %% [markdown]
# ## 第三步：中文分词

# %%
words = ' '.join(jieba.cut(text))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\asus\AppData\Local\Temp\jieba.cache
# Loading model cost 0.969 seconds.
# Prefix dict has been built successfully.

# %% [markdown]
# ## 第四步: 加载掩模图像

# %%
mask_image_url = "mask.png"
mask_image = imageio.imread(mask_image_url)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15972\938459704.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   mask_image = imageio.imread(mask_image_url)

# %% [markdown]
# ## 第五步: 设置支持中文的字体

# %%
font_path = 'C:\WINDOWS\Fonts\SIMSUN.TTC'  # 这里需要一个支持中文的字体文件，宋体
# font_path = 'C:\WINDOWS\Fonts\STLITI.TTF'  # 这里需要一个支持中文的字体文件，华文隶书

# %% [markdown]
# ## 第六步: 创建词云对象，并指定掩模和字体

# %%
wordcloud = WordCloud(font_path=font_path,  # 指定中文字体
                      width=800, height=800,
                      mask=mask_image,  # 这里指定掩模
                      background_color='white',
                      contour_width=0,  # 边缘轮廓宽度
                      contour_color='steelblue',  # 边缘轮廓颜色
                      min_font_size=10).generate(words)

# %% [markdown]
# ## 第七步: 绘制词云

# %%
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud, interpolation="bilinear")  # 使用平滑插值
plt.axis("off")
plt.tight_layout(pad=0)
plt.savefig('wordcloud.png', dpi=800, bbox_inches='tight') # 生成图片

# %% [markdown]
# ## 第七步: 要是用编辑器写的需要手动展示词云图

# %%
#plt.show()
